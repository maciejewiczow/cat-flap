# %%
from PIL import Image, ImageDraw
from matplotlib import pyplot as plt
import numpy as np
from ultralytics import YOLO

# %%
modelPath = "runs/detect/train3/weights/best.pt"

# %%
# imagePath = "C:/Users/Mafciejewicz/Downloads/IMG_20260106_152744.jpg"
# imagePath = "C:/Users/Mafciejewicz/Downloads/IMG_20260106_152744_g.jpg"
# imagePath = "C:/Users/Mafciejewicz/Downloads/IMG_20260106_152448.jpg"
# imagePath = "C:/Users/Mafciejewicz/Downloads/IMG_20260106_152448_g.jpg"
# imagePath = "C:/Users/Mafciejewicz/Downloads/IMG_20260106_152744_p.jpg"
# imagePath = "C:/Users/Mafciejewicz/Downloads/IMG_20260106_152744_p_g.jpg"
imagePath = "C:/Users/Mafciejewicz/Downloads/1000_F_308075192_obNbqwNYv5nwEE2hgvWfQBdFGssWzkOe.jpg"

# %%
model = YOLO(modelPath)

# %%
img = Image.open(imagePath).convert("L")

# %%
plt.imshow(img)

# %%
results = model(img)
# Out:
# 0: 256x352 1 cat, 51.9ms
# Speed: 2.9ms preprocess, 51.9ms inference, 3.1ms postprocess per image at shape (1, 3, 256, 352)

# %%
plt.imshow(results[0].plot()[:, :, ::-1])
